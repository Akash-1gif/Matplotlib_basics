# %%
import matplotlib.pyplot as plt

# %%
x=[1,2]
y=[2,4]
plt.plot(x,y)
plt.scatter(x,y)
plt.show()

# %%
plt.xlabel("x constants")
plt.ylabel("Y constants")
plt.title("my graph")
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x1=[1,3]
y1=[2,4]
c=[0,5]
d=[0,5]
#plotting line 1
plt.scatter(a,b)
plt.plot(a,b,label="line 1")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
#plotting line 2
plt.scatter(c,d)
plt.plot(c,d,label="line 2",markerfacecolor="blue")
#setting axes range
plt.xlim(0,10)
plt.ylim(0,10)
#applying styles
plt.style.use('dark_background')
plt.legend()
plt.show()

# %%
#plotting bar chart
left=[1,2,3,4,5,6]
height=[10,40,25,15,35,22]
l=['A','B','C','D','E','F']
plt.bar(left,height,tick_label=l,width=1,color=['red','green','blue'])
# Out:
# <BarContainer object of 6 artists>

# %%
#plotting histogram
ages=[2,14,4,15,22,3,23,1]
range=(0,25)
bins=10
plt.hist(ages,bins,range,color='red')
# Out:
# (array([2., 2., 0., 0., 0., 1., 1., 0., 1., 1.]),
#  array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
#making a pie chart as per my timetable
act=['eat','sleep','study','college','travel']
hrs=[2,6,5,8,3]
c=['r','g','b','y','m']
plt.pie(hrs,labels=act,colors=c,startangle=90,radius=1.5,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d907e7f4f0>,
# ...
#  [Text(-0.4270514368541781, 1.5937776100450094, 'eat'),
#   Text(-1.5937776200408693, 0.4270513995491214, 'sleep'),
#   Text(-0.6314276634023991, -1.5244012286436228, 'study'),
#   Text(1.593777620040869, -0.4270513995491216, 'college'),
#   Text(0.6314275920400262, 1.5244012582028836, 'travel')])
